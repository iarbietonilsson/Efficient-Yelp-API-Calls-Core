# %% [markdown]
# ## Efficient Yelp API Calls
# ---
# * ### Ingrid Arbieto Nelson

# %% [markdown]
# For this assignment, you will be working with the Yelp API.
#
# * As before, you will use the Yelp API to search your favorite city for a cuisine type of your choice.
#
# * Extract all of the results from your search and compile them into one dataframe using a for loop as shown in the lesson "Code for Efficient API Extraction"
#
# * Save your notebook, commit the change to your repository and submit the repository URL for this assignment.

# %% [markdown]
# ### Imports

# %%
# Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Additional Imports
# os - for saving and loading files
# json - to work with json files
# math - to round up results
# time - to add a short pause to not overwhelm the server
import os, json, math, time

# to make yelpapi calls
from yelpapi import YelpAPI

# progress bar from tqdm_notebook
from tqdm.notebook import tqdm_notebook

# %% [markdown]
# ### Yelp API Credentials

# %%
# Load API Credentials
with open('/Users/sweet/.secret/yelp_api.json', 'r') as f:
    login = json.load(f)

# %%
login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
# Instantiate YelpAPI Variable
yelp = YelpAPI(login['api-key'], timeout_s = 5.0)
yelp

# %% [markdown]
# ### Define Terms & File Path

# %%
# set API call parameters
location = 'SF Bay area, CA'
term = 'Peruvian'

# %%
# get city area
locationname = location.split(',')[0]
locationname
# Out:
# 'SF Bay area'

# %%
# remove spaces
location = locationname.replace(' ', '')
location
# Out:
# 'SFBayarea'

# %%
## Specify fodler for saving data
FOLDER = 'Data/'

os.makedirs(FOLDER, exist_ok = True)
# Specifying JSON_FILE filename (can include a folder)
JSON_FILE = FOLDER+f"{location}-{term}.json"

# %%
JSON_FILE
# Out:
# 'Data/SFBayarea-Peruvian.json'

# %% [markdown]
# ### Check if JSON exists & Create if not

# %%
## Check if JSON_FILE exists
file_exists = os.path.isfile(JSON_FILE)
## If it does not exist: 
if file_exists == False:    
    ## CREATE ANY NEEDED FOLDERS
    # Get the Folder Name only
    folder = os.path.dirname(JSON_FILE)
    
    ## If JSON_FILE included a folder:
    if len(folder)>0:
        # create the folder
        os.makedirs(folder, exist_ok = True)
        
        
    ## INFORM USER AND SAVE EMPTY LIST
    print(f"[i] {JSON_FILE} not found. Saving empty list to file.")
    
    
    ## save the first page of results
    with open(JSON_FILE, 'w') as f:
          json.dump([], f)
        
## If it exists, inform user
else:
    print(f"[i] {JSON_FILE} already exists.")
# Out:
# [i] Data/SFBayarea-Peruvian.json not found. Saving empty list to file.

# %% [markdown]
# ### First API Call
#
# * get first page of results
# * how many total results
# * where is data to save
# * how many results do we get per page

# %%
 with open(JSON_FILE, 'r') as f:
            previous_results = json.load(f)

# %%
# use our yelp_api variable's search_query method to perform our API call
results = yelp.search_query(term = term, location = location)

# %%
## append new results and save to file
previous_results.extend(results['businesses'])

# %%
with open(JSON_FILE, 'w') as f:
         json.dump(previous_results, f)

# %%
type(results)
# Out:
# dict

# %%
len(results)
# Out:
# 3

# %%
results.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
results['total']
# Out:
# 81

# %%
results['region']
# Out:
# {'center': {'longitude': -122.42820739746094, 'latitude': 37.767413217936834}}

# %%
results['businesses']
# Out:
# [{'id': 'Qbr2JG96K6d31NqqAUxf9g',
#   'alias': 'la-mar-cebichería-peruana-san-francisco-4',
#   'name': 'La Mar Cebichería Peruana',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/hI4L8cMY1JY_UKq7ZYBpTw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/la-mar-cebicher%C3%ADa-peruana-san-francisco-4?adjust_creative=gZgX9ur3TQNqXOU_kW4bJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gZgX9ur3TQNqXOU_kW4bJw',
#   'review_count': 4346,
#   'categories': [{'alias': 'latin', 'title': 'Latin American'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'peruvian', 'title': 'Peruvian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.7974182368553,
#    'longitude': -122.395129846558},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$$',
#   'location': {'address1': 'Pier 1 1/2 The Embarcadero',
#    'address2': 'Ste 100',
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94111',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['Pier 1 1/2 The Embarcadero',
#     'Ste 100',
#     'San Francisco, CA 94111']},
#   'phone': '+14153978880',
#   'display_phone': '(415) 397-8880',
#   'distance': 4425.130367448837},
#  {'id': 'r7RwvYMwxDuK3u26fHbYDA',
#   'alias': 'limón-san-francisco-7',
#   'name': 'Limón',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/k0K31LGP-3a05UlYOtbsDA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lim%C3%B3n-san-francisco-7?adjust_creative=gZgX9ur3TQNqXOU_kW4bJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gZgX9ur3TQNqXOU_kW4bJw',
#   'review_count': 3510,
#   'categories': [{'alias': 'peruvian', 'title': 'Peruvian'},
#    {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.7570514, 'longitude': -122.416461},
#   'transactions': ['restaurant_reservation', 'pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1001 S Van Ness Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94110',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1001 S Van Ness Ave', 'San Francisco, CA 94110']},
#   'phone': '+14158212134',
#   'display_phone': '(415) 821-2134',
#   'distance': 1547.1713974304798},
#  {'id': 'iXoLJWjbcXCO43RT-H0uQQ',
#   'alias': 'jaranita-san-francisco-4',
#   'name': 'Jaranita',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/jgM34JZztq7h1LU1zoUuUg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/jaranita-san-francisco-4?adjust_creative=gZgX9ur3TQNqXOU_kW4bJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gZgX9ur3TQNqXOU_kW4bJw',
#   'review_count': 425,
#   'categories': [{'alias': 'peruvian', 'title': 'Peruvian'},
#    {'alias': 'latin', 'title': 'Latin American'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 37.80024, 'longitude': -122.437539},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '3340 Steiner St',
#    'address2': None,
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94123',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['3340 Steiner St', 'San Francisco, CA 94123']},
#   'phone': '+14156559585',
#   'display_phone': '(415) 655-9585',
#   'distance': 3741.4127629058353},
#  {'id': '0l7MgfpsIi2-vTuCVdDccg',
#   'alias': 'mochica-san-francisco-2',
#   'name': 'Mochica',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/a43PuVYBwPsNk3k7M79cpg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mochica-san-francisco-2?adjust_creative=gZgX9ur3TQNqXOU_kW4bJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gZgX9ur3TQNqXOU_kW4bJw',
#   'review_count': 752,
#   'categories': [{'alias': 'peruvian', 'title': 'Peruvian'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.76242, 'longitude': -122.39718},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1469 18th St',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94107',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1469 18th St', 'San Francisco, CA 94107']},
#   'phone': '+14152780480',
#   'display_phone': '(415) 278-0480',
#   'distance': 2773.6969514561742},
#  {'id': 'DLpHmXitZxDLdqTwydUSdA',
#   'alias': 'la-fusión-san-francisco-2',
#   'name': 'La Fusión',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/oRfx291jFQc0ZhfLjIOY3w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/la-fusi%C3%B3n-san-francisco-2?adjust_creative=gZgX9ur3TQNqXOU_kW4bJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gZgX9ur3TQNqXOU_kW4bJw',
#   'review_count': 1201,
#   'categories': [{'alias': 'latin', 'title': 'Latin American'},
#    {'alias': 'comfortfood', 'title': 'Comfort Food'},
#    {'alias': 'peruvian', 'title': 'Peruvian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 37.7916357455614,
#    'longitude': -122.403691572642},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '475 Pine St',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94104',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['475 Pine St', 'San Francisco, CA 94104']},
#   'phone': '+14157810894',
#   'display_phone': '(415) 781-0894',
#   'distance': 3449.165620846087},
#  {'id': '8VurRDEj1RpimenhgTmyFQ',
#   'alias': 'kaiyō-rooftop-san-francisco-5',
#   'name': 'KAIYŌ Rooftop',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/IpnkGDpsm94wGzTAdFekPg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/kaiy%C5%8D-rooftop-san-francisco-5?adjust_creative=gZgX9ur3TQNqXOU_kW4bJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gZgX9ur3TQNqXOU_kW4bJw',
#   'review_count': 527,
#   'categories': [{'alias': 'peruvian', 'title': 'Peruvian'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.77882, 'longitude': -122.3924},
#   'transactions': [],
#   'location': {'address1': '701 3rd St',
#    'address2': 'Fl 12',
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94105',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['701 3rd St', 'Fl 12', 'San Francisco, CA 94105']},
#   'phone': '+14158008141',
#   'display_phone': '(415) 800-8141',
#   'distance': 3393.5907628478535},
#  {'id': 'E0ceJh3NitoNjlZxmvCVLQ',
#   'alias': 'sanguchon-eatery-san-francisco',
#   'name': 'Sanguchon Eatery',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/QMYOcF_CaI32nhBqIAxahQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sanguchon-eatery-san-francisco?adjust_creative=gZgX9ur3TQNqXOU_kW4bJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gZgX9ur3TQNqXOU_kW4bJw',
#   'review_count': 111,
#   'categories': [{'alias': 'peruvian', 'title': 'Peruvian'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 37.75408, 'longitude': -122.42101},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1182 Valencia St',
#    'address2': None,
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94110',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1182 Valencia St', 'San Francisco, CA 94110']},
#   'phone': '+14157664317',
#   'display_phone': '(415) 766-4317',
#   'distance': 1613.0722437387783},
#  {'id': '1DDbE3XJF6lFL_KpU6Pmww',
#   'alias': 'mi-lindo-perú-san-francisco-6',
#   'name': 'Mi Lindo Perú',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/WDFdWzB3zk5_mb96QiNroA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mi-lindo-per%C3%BA-san-francisco-6?adjust_creative=gZgX9ur3TQNqXOU_kW4bJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gZgX9ur3TQNqXOU_kW4bJw',
#   'review_count': 781,
#   'categories': [{'alias': 'peruvian', 'title': 'Peruvian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.7450935396928,
#    'longitude': -122.420390950891},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '3226 Mission St',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94110',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['3226 Mission St', 'San Francisco, CA 94110']},
#   'phone': '+14156424897',
#   'display_phone': '(415) 642-4897',
#   'distance': 2575.207095269517},
#  {'id': 'Lr-uGQ8VxaYLEIKTLmA2qQ',
#   'alias': 'la-fina-estampa-san-francisco',
#   'name': 'La Fina Estampa',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Tk-dAjE6tL1ZfzZQcp0jHw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/la-fina-estampa-san-francisco?adjust_creative=gZgX9ur3TQNqXOU_kW4bJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gZgX9ur3TQNqXOU_kW4bJw',
#   'review_count': 274,
#   'categories': [{'alias': 'peruvian', 'title': 'Peruvian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.788479, 'longitude': -122.420715},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '1407 Bush St',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94109',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1407 Bush St', 'San Francisco, CA 94109']},
#   'phone': '+14153451685',
#   'display_phone': '(415) 345-1685',
#   'distance': 2419.957780349788},
#  {'id': 'BjuRomoFDALM-ukqbpVpAw',
#   'alias': 'fresca-san-francisco-6',
#   'name': 'Fresca',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/G-xgajK_JYa0iFNuU9Q1WQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/fresca-san-francisco-6?adjust_creative=gZgX9ur3TQNqXOU_kW4bJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gZgX9ur3TQNqXOU_kW4bJw',
#   'review_count': 434,
#   'categories': [{'alias': 'peruvian', 'title': 'Peruvian'},
#    {'alias': 'wine_bars', 'title': 'Wine Bars'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.7639084, 'longitude': -122.465889},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '737 Irving St',
#    'address2': None,
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94122',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['737 Irving St', 'San Francisco, CA 94122']},
#   'phone': '+14157425727',
#   'display_phone': '(415) 742-5727',
#   'distance': 3339.737814685907},
#  {'id': 'RB1sjHEaT3Hbn2Fohhx-Hw',
#   'alias': 'el-aji-peruvian-restaurant-san-francisco',
#   'name': 'El Aji Peruvian Restaurant',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/DHPmKTcuVj9rtHC5Rc5XYg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/el-aji-peruvian-restaurant-san-francisco?adjust_creative=gZgX9ur3TQNqXOU_kW4bJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gZgX9ur3TQNqXOU_kW4bJw',
#   'review_count': 98,
#   'categories': [{'alias': 'peruvian', 'title': 'Peruvian'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'desserts', 'title': 'Desserts'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.74883, 'longitude': -122.41771},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '3015 Mission St',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94110',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['3015 Mission St', 'San Francisco, CA 94110']},
#   'phone': '+14156587349',
#   'display_phone': '(415) 658-7349',
#   'distance': 2254.125048016847},
#  {'id': 'lKj4XgtSKh20UlHBVHq4Ag',
#   'alias': 'el-porteño-san-francisco-6',
#   'name': 'El Porteño',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zt3oFfXl0H9p2mKHeXriag/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/el-porte%C3%B1o-san-francisco-6?adjust_creative=gZgX9ur3TQNqXOU_kW4bJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gZgX9ur3TQNqXOU_kW4bJw',
#   'review_count': 190,
#   'categories': [{'alias': 'peruvian', 'title': 'Peruvian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.71584, 'longitude': -122.44127},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '5173 Mission St',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94112',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['5173 Mission St', 'San Francisco, CA 94112']},
#   'phone': '+14155861206',
#   'display_phone': '(415) 586-1206',
#   'distance': 5845.003023720573},
#  {'id': 'rM6pPB_qmQ3de5yGpfLT1g',
#   'alias': 'lomo-libre-cantina-san-francisco',
#   'name': 'Lomo Libre Cantina',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/rAT5Kr1ed5rCMVKHBgDYRw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lomo-libre-cantina-san-francisco?adjust_creative=gZgX9ur3TQNqXOU_kW4bJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gZgX9ur3TQNqXOU_kW4bJw',
#   'review_count': 97,
#   'categories': [{'alias': 'peruvian', 'title': 'Peruvian'},
#    {'alias': 'latin', 'title': 'Latin American'},
#    {'alias': 'sportsbars', 'title': 'Sports Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 37.76381650444467, 'longitude': -122.4777046},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1824 Irving St',
#    'address2': None,
#    'address3': None,
#    'city': 'San Francisco',
#    'zip_code': '94122',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1824 Irving St', 'San Francisco, CA 94122']},
#   'phone': '+14155718403',
#   'display_phone': '(415) 571-8403',
#   'distance': 4369.246247184127},
#  {'id': '_Iupdt0IslH_jU8zkKcWLA',
#   'alias': 'pica-pica-arepa-kitchen-san-francisco',
#   'name': 'Pica Pica Arepa Kitchen',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/hAWS9IidumamHodFIUikIA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pica-pica-arepa-kitchen-san-francisco?adjust_creative=gZgX9ur3TQNqXOU_kW4bJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gZgX9ur3TQNqXOU_kW4bJw',
#   'review_count': 1656,
#   'categories': [{'alias': 'gluten_free', 'title': 'Gluten-Free'},
#    {'alias': 'latin', 'title': 'Latin American'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.76646996177495,
#    'longitude': -122.42190694110414},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '401 Valencia St',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94103',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['401 Valencia St', 'San Francisco, CA 94103']},
#   'phone': '+14154005453',
#   'display_phone': '(415) 400-5453',
#   'distance': 563.6573480438591},
#  {'id': '_TVBDjUzNKi4HEmUT4yPGA',
#   'alias': 'kaiyō-cow-hollow-san-francisco',
#   'name': 'KAIYŌ Cow Hollow',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Lkyv0Z48ip8WpBz2DdcXqA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/kaiy%C5%8D-cow-hollow-san-francisco?adjust_creative=gZgX9ur3TQNqXOU_kW4bJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gZgX9ur3TQNqXOU_kW4bJw',
#   'review_count': 623,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'peruvian', 'title': 'Peruvian'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.79801, 'longitude': -122.42967},
#   'transactions': ['delivery'],
#   'location': {'address1': '1838 Union St',
#    'address2': '',
#    'address3': None,
#    'city': 'San Francisco',
#    'zip_code': '94123',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1838 Union St', 'San Francisco, CA 94123']},
#   'phone': '+14155254804',
#   'display_phone': '(415) 525-4804',
#   'distance': 3400.4606060334936},
#  {'id': '5o8ITvsF6GG1fmhqHOdLLg',
#   'alias': 'rockoto-peruvian-cuisine-south-san-francisco-2',
#   'name': 'Rockoto Peruvian cuisine',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/8vmz1zIsPxWgyLupc6OtTA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/rockoto-peruvian-cuisine-south-san-francisco-2?adjust_creative=gZgX9ur3TQNqXOU_kW4bJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gZgX9ur3TQNqXOU_kW4bJw',
#   'review_count': 67,
#   'categories': [{'alias': 'peruvian', 'title': 'Peruvian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 37.6545022, 'longitude': -122.410557},
#   'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#   'location': {'address1': '207 Linden Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'South San Francisco',
#    'zip_code': '94080',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['207 Linden Ave', 'South San Francisco, CA 94080']},
#   'phone': '+16508733434',
#   'display_phone': '(650) 873-3434',
#   'distance': 12650.759784807396},
#  {'id': 'vsiJDU-0_cdYrf1Otawtbw',
#   'alias': 'piqueos-san-francisco',
#   'name': "Piqueo's",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/2i5ApYpDD4PQHA3qjFUu-Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/piqueos-san-francisco?adjust_creative=gZgX9ur3TQNqXOU_kW4bJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gZgX9ur3TQNqXOU_kW4bJw',
#   'review_count': 754,
#   'categories': [{'alias': 'latin', 'title': 'Latin American'},
#    {'alias': 'peruvian', 'title': 'Peruvian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.7387299, 'longitude': -122.41407},
#   'transactions': ['delivery'],
#   'price': '$$$',
#   'location': {'address1': '830 Cortland Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94110',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['830 Cortland Ave', 'San Francisco, CA 94110']},
#   'phone': '+14152828812',
#   'display_phone': '(415) 282-8812',
#   'distance': 3419.6355960602014},
#  {'id': 'Uq3u_kbGVGLjEDVU45WLog',
#   'alias': 'el-mono-el-cerrito',
#   'name': 'El Mono',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/0WhBj_dUfe8eOr1QFO3Dlg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/el-mono-el-cerrito?adjust_creative=gZgX9ur3TQNqXOU_kW4bJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gZgX9ur3TQNqXOU_kW4bJw',
#   'review_count': 2139,
#   'categories': [{'alias': 'peruvian', 'title': 'Peruvian'},
#    {'alias': 'latin', 'title': 'Latin American'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 37.926926, 'longitude': -122.3190558},
#   'transactions': ['restaurant_reservation', 'pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '11720 San Pablo Ave',
#    'address2': 'Ste B',
#    'address3': '',
#    'city': 'El Cerrito',
#    'zip_code': '94530',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['11720 San Pablo Ave',
#     'Ste B',
#     'El Cerrito, CA 94530']},
#   'phone': '+15107788884',
#   'display_phone': '(510) 778-8884',
#   'distance': 20160.725203492984},
#  {'id': 'eCRpZzBx5NNHVncFzRwcmg',
#   'alias': 'francos-latin-table-san-francisco-2',
#   'name': "Franco's Latin Table",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/r5WDSb_rJNZWC0rSs7HhNA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/francos-latin-table-san-francisco-2?adjust_creative=gZgX9ur3TQNqXOU_kW4bJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gZgX9ur3TQNqXOU_kW4bJw',
#   'review_count': 225,
#   'categories': [{'alias': 'latin', 'title': 'Latin American'},
#    {'alias': 'peruvian', 'title': 'Peruvian'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 37.7406245, 'longitude': -122.4663397},
#   'transactions': ['restaurant_reservation', 'pickup'],
#   'price': '$$$',
#   'location': {'address1': '24 W Portal Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94127',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['24 W Portal Ave', 'San Francisco, CA 94127']},
#   'phone': '+14157598087',
#   'display_phone': '(415) 759-8087',
#   'distance': 4484.623295836859},
#  {'id': 'oezxL8xcd4jkG2C5u8jLaA',
#   'alias': 'el-porteño-ii-restaurant-and-bar-san-francisco',
#   'name': 'El Porteño II Restaurant & Bar',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/S6IAzJfAZvm18zyJ0P1hTg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/el-porte%C3%B1o-ii-restaurant-and-bar-san-francisco?adjust_creative=gZgX9ur3TQNqXOU_kW4bJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=gZgX9ur3TQNqXOU_kW4bJw',
#   'review_count': 49,
#   'categories': [{'alias': 'peruvian', 'title': 'Peruvian'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 37.760501, 'longitude': -122.418991},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '2293 Mission St',
#    'address2': None,
#    'address3': '',
#    'city': 'San Francisco',
#    'zip_code': '94110',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['2293 Mission St', 'San Francisco, CA 94110']},
#   'phone': '+14158726188',
#   'display_phone': '(415) 872-6188',
#   'distance': 1116.7391072165296}]

# %%
## How many results total?
pd.DataFrame(results['businesses'])
# Out:
#                         id                                           alias  \
# 0   Qbr2JG96K6d31NqqAUxf9g       la-mar-cebichería-peruana-san-francisco-4
# 1   r7RwvYMwxDuK3u26fHbYDA                           limón-san-francisco-7
# 2   iXoLJWjbcXCO43RT-H0uQQ                        jaranita-san-francisco-4
# 3   0l7MgfpsIi2-vTuCVdDccg                         mochica-san-francisco-2
# 4   DLpHmXitZxDLdqTwydUSdA                       la-fusión-san-francisco-2
# 5   8VurRDEj1RpimenhgTmyFQ                   kaiyō-rooftop-san-francisco-5
# 6   E0ceJh3NitoNjlZxmvCVLQ                  sanguchon-eatery-san-francisco
# 7   1DDbE3XJF6lFL_KpU6Pmww                   mi-lindo-perú-san-francisco-6
# 8   Lr-uGQ8VxaYLEIKTLmA2qQ                   la-fina-estampa-san-francisco
# 9   BjuRomoFDALM-ukqbpVpAw                          fresca-san-francisco-6
# 10  RB1sjHEaT3Hbn2Fohhx-Hw        el-aji-peruvian-restaurant-san-francisco
# 11  lKj4XgtSKh20UlHBVHq4Ag                      el-porteño-san-francisco-6
# 12  rM6pPB_qmQ3de5yGpfLT1g                lomo-libre-cantina-san-francisco
# 13  _Iupdt0IslH_jU8zkKcWLA           pica-pica-arepa-kitchen-san-francisco
# 14  _TVBDjUzNKi4HEmUT4yPGA                  kaiyō-cow-hollow-san-francisco
# 15  5o8ITvsF6GG1fmhqHOdLLg  rockoto-peruvian-cuisine-south-san-francisco-2
# 16  vsiJDU-0_cdYrf1Otawtbw                           piqueos-san-francisco
# 17  Uq3u_kbGVGLjEDVU45WLog                              el-mono-el-cerrito
# 18  eCRpZzBx5NNHVncFzRwcmg             francos-latin-table-san-francisco-2
# 19  oezxL8xcd4jkG2C5u8jLaA  el-porteño-ii-restaurant-and-bar-san-francisco
#
#                               name  \
# 0        La Mar Cebichería Peruana
# 1                            Limón
# 2                         Jaranita
# 3                          Mochica
# 4                        La Fusión
# 5                    KAIYŌ Rooftop
# 6                 Sanguchon Eatery
# 7                    Mi Lindo Perú
# 8                  La Fina Estampa
# 9                           Fresca
# 10      El Aji Peruvian Restaurant
# 11                      El Porteño
# 12              Lomo Libre Cantina
# 13         Pica Pica Arepa Kitchen
# 14                KAIYŌ Cow Hollow
# 15        Rockoto Peruvian cuisine
# 16                        Piqueo's
# 17                         El Mono
# 18            Franco's Latin Table
# 19  El Porteño II Restaurant & Bar
#
#                                             image_url  is_closed  \
# 0   https://s3-media4.fl.yelpcdn.com/bphoto/hI4L8c...      False
# 1   https://s3-media2.fl.yelpcdn.com/bphoto/k0K31L...      False
# 2   https://s3-media3.fl.yelpcdn.com/bphoto/jgM34J...      False
# 3   https://s3-media3.fl.yelpcdn.com/bphoto/a43PuV...      False
# 4   https://s3-media2.fl.yelpcdn.com/bphoto/oRfx29...      False
# 5   https://s3-media4.fl.yelpcdn.com/bphoto/IpnkGD...      False
# 6   https://s3-media1.fl.yelpcdn.com/bphoto/QMYOcF...      False
# 7   https://s3-media1.fl.yelpcdn.com/bphoto/WDFdWz...      False
# 8   https://s3-media2.fl.yelpcdn.com/bphoto/Tk-dAj...      False
# 9   https://s3-media2.fl.yelpcdn.com/bphoto/G-xgaj...      False
# 10  https://s3-media2.fl.yelpcdn.com/bphoto/DHPmKT...      False
# 11  https://s3-media2.fl.yelpcdn.com/bphoto/zt3oFf...      False
# 12  https://s3-media3.fl.yelpcdn.com/bphoto/rAT5Kr...      False
# 13  https://s3-media1.fl.yelpcdn.com/bphoto/hAWS9I...      False
# 14  https://s3-media1.fl.yelpcdn.com/bphoto/Lkyv0Z...      False
# 15  https://s3-media1.fl.yelpcdn.com/bphoto/8vmz1z...      False
# 16  https://s3-media4.fl.yelpcdn.com/bphoto/2i5ApY...      False
# 17  https://s3-media1.fl.yelpcdn.com/bphoto/0WhBj_...      False
# 18  https://s3-media4.fl.yelpcdn.com/bphoto/r5WDSb...      False
# 19  https://s3-media1.fl.yelpcdn.com/bphoto/S6IAzJ...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/la-mar-cebicher%C3%AD...          4346
# 1   https://www.yelp.com/biz/lim%C3%B3n-san-franci...          3510
# 2   https://www.yelp.com/biz/jaranita-san-francisc...           425
# 3   https://www.yelp.com/biz/mochica-san-francisco...           752
# 4   https://www.yelp.com/biz/la-fusi%C3%B3n-san-fr...          1201
# 5   https://www.yelp.com/biz/kaiy%C5%8D-rooftop-sa...           527
# 6   https://www.yelp.com/biz/sanguchon-eatery-san-...           111
# 7   https://www.yelp.com/biz/mi-lindo-per%C3%BA-sa...           781
# 8   https://www.yelp.com/biz/la-fina-estampa-san-f...           274
# 9   https://www.yelp.com/biz/fresca-san-francisco-...           434
# 10  https://www.yelp.com/biz/el-aji-peruvian-resta...            98
# 11  https://www.yelp.com/biz/el-porte%C3%B1o-san-f...           190
# 12  https://www.yelp.com/biz/lomo-libre-cantina-sa...            97
# 13  https://www.yelp.com/biz/pica-pica-arepa-kitch...          1656
# 14  https://www.yelp.com/biz/kaiy%C5%8D-cow-hollow...           623
# 15  https://www.yelp.com/biz/rockoto-peruvian-cuis...            67
# 16  https://www.yelp.com/biz/piqueos-san-francisco...           754
# 17  https://www.yelp.com/biz/el-mono-el-cerrito?ad...          2139
# 18  https://www.yelp.com/biz/francos-latin-table-s...           225
# 19  https://www.yelp.com/biz/el-porte%C3%B1o-ii-re...            49
#
#                                            categories  rating  \
# 0   [{'alias': 'latin', 'title': 'Latin American'}...     4.0
# 1   [{'alias': 'peruvian', 'title': 'Peruvian'}, {...     4.0
# 2   [{'alias': 'peruvian', 'title': 'Peruvian'}, {...     4.5
# 3   [{'alias': 'peruvian', 'title': 'Peruvian'}, {...     4.0
# 4   [{'alias': 'latin', 'title': 'Latin American'}...     4.5
# 5   [{'alias': 'peruvian', 'title': 'Peruvian'}, {...     4.0
# 6   [{'alias': 'peruvian', 'title': 'Peruvian'}, {...     4.5
# 7        [{'alias': 'peruvian', 'title': 'Peruvian'}]     4.0
# 8        [{'alias': 'peruvian', 'title': 'Peruvian'}]     4.0
# 9   [{'alias': 'peruvian', 'title': 'Peruvian'}, {...     4.0
# 10  [{'alias': 'peruvian', 'title': 'Peruvian'}, {...     4.0
# 11       [{'alias': 'peruvian', 'title': 'Peruvian'}]     4.0
# 12  [{'alias': 'peruvian', 'title': 'Peruvian'}, {...     4.5
# 13  [{'alias': 'gluten_free', 'title': 'Gluten-Fre...     4.0
# 14  [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.0
# 15       [{'alias': 'peruvian', 'title': 'Peruvian'}]     4.5
# 16  [{'alias': 'latin', 'title': 'Latin American'}...     4.0
# 17  [{'alias': 'peruvian', 'title': 'Peruvian'}, {...     4.5
# 18  [{'alias': 'latin', 'title': 'Latin American'}...     4.5
# 19  [{'alias': 'peruvian', 'title': 'Peruvian'}, {...     4.0
#
#                                           coordinates  \
# 0   {'latitude': 37.7974182368553, 'longitude': -1...
# 1   {'latitude': 37.7570514, 'longitude': -122.416...
# 2    {'latitude': 37.80024, 'longitude': -122.437539}
# 3     {'latitude': 37.76242, 'longitude': -122.39718}
# 4   {'latitude': 37.7916357455614, 'longitude': -1...
# 5      {'latitude': 37.77882, 'longitude': -122.3924}
# 6     {'latitude': 37.75408, 'longitude': -122.42101}
# 7   {'latitude': 37.7450935396928, 'longitude': -1...
# 8   {'latitude': 37.788479, 'longitude': -122.420715}
# 9   {'latitude': 37.7639084, 'longitude': -122.465...
# 10    {'latitude': 37.74883, 'longitude': -122.41771}
# 11    {'latitude': 37.71584, 'longitude': -122.44127}
# 12  {'latitude': 37.76381650444467, 'longitude': -...
# 13  {'latitude': 37.76646996177495, 'longitude': -...
# 14    {'latitude': 37.79801, 'longitude': -122.42967}
# 15  {'latitude': 37.6545022, 'longitude': -122.410...
# 16  {'latitude': 37.7387299, 'longitude': -122.41407}
# 17  {'latitude': 37.926926, 'longitude': -122.3190...
# 18  {'latitude': 37.7406245, 'longitude': -122.466...
# 19  {'latitude': 37.760501, 'longitude': -122.418991}
#
#                                   transactions price  \
# 0                           [pickup, delivery]   $$$
# 1   [restaurant_reservation, pickup, delivery]    $$
# 2                           [pickup, delivery]    $$
# 3                           [pickup, delivery]    $$
# 4                                   [delivery]    $$
# 5                                           []   NaN
# 6                           [pickup, delivery]    $$
# 7                           [pickup, delivery]    $$
# 8                                   [delivery]    $$
# 9                           [pickup, delivery]    $$
# 10                          [pickup, delivery]    $$
# 11                          [pickup, delivery]    $$
# 12                          [pickup, delivery]    $$
# 13                          [pickup, delivery]    $$
# 14                                  [delivery]   NaN
# 15  [pickup, restaurant_reservation, delivery]   NaN
# 16                                  [delivery]   $$$
# 17  [restaurant_reservation, pickup, delivery]    $$
# 18            [restaurant_reservation, pickup]   $$$
# 19                          [pickup, delivery]    $$
#
#                                              location         phone  \
# 0   {'address1': 'Pier 1 1/2 The Embarcadero', 'ad...  +14153978880
# 1   {'address1': '1001 S Van Ness Ave', 'address2'...  +14158212134
# 2   {'address1': '3340 Steiner St', 'address2': No...  +14156559585
# 3   {'address1': '1469 18th St', 'address2': '', '...  +14152780480
# 4   {'address1': '475 Pine St', 'address2': '', 'a...  +14157810894
# 5   {'address1': '701 3rd St', 'address2': 'Fl 12'...  +14158008141
# 6   {'address1': '1182 Valencia St', 'address2': N...  +14157664317
# 7   {'address1': '3226 Mission St', 'address2': ''...  +14156424897
# 8   {'address1': '1407 Bush St', 'address2': '', '...  +14153451685
# 9   {'address1': '737 Irving St', 'address2': None...  +14157425727
# 10  {'address1': '3015 Mission St', 'address2': ''...  +14156587349
# 11  {'address1': '5173 Mission St', 'address2': ''...  +14155861206
# 12  {'address1': '1824 Irving St', 'address2': Non...  +14155718403
# 13  {'address1': '401 Valencia St', 'address2': ''...  +14154005453
# 14  {'address1': '1838 Union St', 'address2': '', ...  +14155254804
# 15  {'address1': '207 Linden Ave', 'address2': '',...  +16508733434
# 16  {'address1': '830 Cortland Ave', 'address2': '...  +14152828812
# 17  {'address1': '11720 San Pablo Ave', 'address2'...  +15107788884
# 18  {'address1': '24 W Portal Ave', 'address2': No...  +14157598087
# 19  {'address1': '2293 Mission St', 'address2': No...  +14158726188
#
#      display_phone      distance
# 0   (415) 397-8880   4425.130367
# 1   (415) 821-2134   1547.171397
# 2   (415) 655-9585   3741.412763
# 3   (415) 278-0480   2773.696951
# 4   (415) 781-0894   3449.165621
# 5   (415) 800-8141   3393.590763
# 6   (415) 766-4317   1613.072244
# 7   (415) 642-4897   2575.207095
# 8   (415) 345-1685   2419.957780
# 9   (415) 742-5727   3339.737815
# 10  (415) 658-7349   2254.125048
# 11  (415) 586-1206   5845.003024
# 12  (415) 571-8403   4369.246247
# 13  (415) 400-5453    563.657348
# 14  (415) 525-4804   3400.460606
# 15  (650) 873-3434  12650.759785
# 16  (415) 282-8812   3419.635596
# 17  (510) 778-8884  20160.725203
# 18  (415) 759-8087   4484.623296
# 19  (415) 872-6188   1116.739107

# %%
## How many did we get the details for?
results_per_page = len(results['businesses'])
results_per_page
# Out:
# 20

# %%
# Use math.ceil to round up for the total number of pages of results.
n_pages = math.ceil((results['total'])/ results_per_page)
n_pages
# Out:
# 5

# %%
for i in tqdm_notebook(range(1,n_pages+1)):
    ## The block of code we want to TRY to run
    try:
        
        time.sleep(.2)
        
        ## Read in results in progress file and check the length
        with open(JSON_FILE, 'r') as f:
            previous_results = json.load(f)
        
        ## save number of results for to use as offset
        n_results = len(previous_results)
    
        
        ## use n_results as the OFFSET 
        results = yelp.search_query(location = location, term = term,
                                   offset = n_results+1)

        ## append new results and save to file
        previous_results.extend(results['businesses'])
        
        with open(JSON_FILE, 'w') as f:
            json.dump(previous_results, f)

            
    ## What to do if we get an error/exception.
    except Exception as e:
        print(' [!] ERROR', e)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]

# %% [markdown]
# ### Open JSON file with Pandas

# %%
df = pd.read_json(JSON_FILE)

# %%
df.head()
# Out:
#                        id                                      alias  \
# 0  Qbr2JG96K6d31NqqAUxf9g  la-mar-cebichería-peruana-san-francisco-4
# 1  r7RwvYMwxDuK3u26fHbYDA                      limón-san-francisco-7
# 2  iXoLJWjbcXCO43RT-H0uQQ                   jaranita-san-francisco-4
# 3  0l7MgfpsIi2-vTuCVdDccg                    mochica-san-francisco-2
# 4  DLpHmXitZxDLdqTwydUSdA                  la-fusión-san-francisco-2
#
#                         name  \
# 0  La Mar Cebichería Peruana
# 1                      Limón
# 2                   Jaranita
# 3                    Mochica
# 4                  La Fusión
#
#                                            image_url  is_closed  \
# 0  https://s3-media4.fl.yelpcdn.com/bphoto/hI4L8c...      False
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/k0K31L...      False
# 2  https://s3-media3.fl.yelpcdn.com/bphoto/jgM34J...      False
# 3  https://s3-media3.fl.yelpcdn.com/bphoto/a43PuV...      False
# 4  https://s3-media2.fl.yelpcdn.com/bphoto/oRfx29...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/la-mar-cebicher%C3%AD...          4346
# 1  https://www.yelp.com/biz/lim%C3%B3n-san-franci...          3510
# 2  https://www.yelp.com/biz/jaranita-san-francisc...           425
# 3  https://www.yelp.com/biz/mochica-san-francisco...           752
# 4  https://www.yelp.com/biz/la-fusi%C3%B3n-san-fr...          1201
#
#                                           categories  rating  \
# 0  [{'alias': 'latin', 'title': 'Latin American'}...     4.0
# 1  [{'alias': 'peruvian', 'title': 'Peruvian'}, {...     4.0
# 2  [{'alias': 'peruvian', 'title': 'Peruvian'}, {...     4.5
# 3  [{'alias': 'peruvian', 'title': 'Peruvian'}, {...     4.0
# 4  [{'alias': 'latin', 'title': 'Latin American'}...     4.5
#
#                                          coordinates  \
# 0  {'latitude': 37.7974182368553, 'longitude': -1...
# 1  {'latitude': 37.7570514, 'longitude': -122.416...
# 2   {'latitude': 37.80024, 'longitude': -122.437539}
# 3    {'latitude': 37.76242, 'longitude': -122.39718}
# 4  {'latitude': 37.7916357455614, 'longitude': -1...
#
#                                  transactions price  \
# 0                          [pickup, delivery]   $$$
# 1  [restaurant_reservation, pickup, delivery]    $$
# 2                          [pickup, delivery]    $$
# 3                          [pickup, delivery]    $$
# 4                                  [delivery]    $$
#
#                                             location         phone  \
# 0  {'address1': 'Pier 1 1/2 The Embarcadero', 'ad...  +14153978880
# 1  {'address1': '1001 S Van Ness Ave', 'address2'...  +14158212134
# 2  {'address1': '3340 Steiner St', 'address2': No...  +14156559585
# 3  {'address1': '1469 18th St', 'address2': '', '...  +14152780480
# 4  {'address1': '475 Pine St', 'address2': '', 'a...  +14157810894
#
#     display_phone     distance
# 0  (415) 397-8880  4425.130367
# 1  (415) 821-2134  1547.171397
# 2  (415) 655-9585  3741.412763
# 3  (415) 278-0480  2773.696951
# 4  (415) 781-0894  3449.165621

# %%
pd.set_option('display.max_rows', 100)

# %%
df['name'].value_counts()
# Out:
# Limón                                   3
# Cholita Linda                           3
# Venga Empanadas                         2
# Fresca                                  2
# Espetus Churrascaria                    1
# La Marcha Tapas Bar                     1
# Mr. Pollo                               1
# Las Tinajas Restaurant                  1
# Truly Food Truck                        1
# Shakewell                               1
# Villa Del Sol Argentinian Restaurant    1
# Radio Habana Social Club                1
# La Furia Chalaca                        1
# Limón Rotisserie                        1
# B44 Catalan Bistro                      1
# Pucquio                                 1
# The Green Enchilada                     1
# Stew The Llama                          1
# Limón Rotisserie Food Truck             1
# La Mar Cebichería Peruana               1
# Kiraku                                  1
# MaMo                                    1
# San Vicente Restaurant & Sport Bar      1
# Cafe La Taza                            1
# Bocanova                                1
# Pollo Campero                           1
# Bar Cesar                               1
# Fonda                                   1
# Clock Bar                               1
# Parche                                  1
# Oye Managua                             1
# Shaska Deli Cafe                        1
# El Calamar                              1
# Vanessa's Bistro                        1
# Cantoo Latin Asian Rotisserie           1
# Los Cocos Salvadoran Restaurant         1
# La Casona Grill                         1
# Caña Cuban Parlor & Cafe                1
# Paradita Eatery                         1
# El Toro Loco                            1
# El Aji Peruvian Restaurant              1
# Piqueo's                                1
# Rockoto Peruvian cuisine                1
# KAIYŌ Cow Hollow                        1
# Pica Pica Arepa Kitchen                 1
# Lomo Libre Cantina                      1
# El Porteño                              1
# La Fina Estampa                         1
# Franco's Latin Table                    1
# Mi Lindo Perú                           1
# Sanguchon Eatery                        1
# KAIYŌ Rooftop                           1
# La Fusión                               1
# Mochica                                 1
# Jaranita                                1
# El Mono                                 1
# El Porteño II Restaurant & Bar          1
# Sol Food Mill Valley                    1
# Il Pollaio                              1
# Gilberths Latin Fusion                  1
# Chao Pescao                             1
# Duende                                  1
# El Porteño Empanadas                    1
# El Nuevo Frutilandia                    1
# Poc-Chuc                                1
# El Techo                                1
# Rosi's Alfajores                        1
# Parada 22                               1
# Kimbara                                 1
# Cha Cha Cha                             1
# Lolinda                                 1
# Waterfall                               1
# Artesano                                1
# Alfajores Peruvian Cookies              1
# Name: name, dtype: int64

# %%
pd.reset_option("display.max_rows")

# %%
## convert the filename to a .csv.gz
csv_file = JSON_FILE.replace('.json','.csv.gz')
csv_file
# Out:
# 'Data/SFBayarea-Peruvian.csv.gz'

# %%
## Save it as a compressed csv (to save space)
df.to_csv(csv_file, compression = 'gzip', index = False)
